# %% [markdown]
# # Gráfico de barras

# %% [markdown]
# ## ¿Cuándo utilizar?
#
# Cuando quiero comparar las magnitudes de variables númericas de diferentes grupos en mis datos.
#
# Quiero enfatizar cambios de magnitud.
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ## ¿Cuándo no utilizar?
#
# Si tengo demasiadas categorías a comparar (muchos puntos en el eje X).
#
# Si quiero analizar los registros individuales en mi dataset y tengo muchos registros.
#
# Si quiero comparar proporciones.
#
# Si me interesa investigar acerda de las distribuciones de mis datos
#
# ![image.png](attachment:image.png)
#
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ### Consejos
# No utilizar colores en las barras de manera innecesaria.
#
# El eje Y siempre empieza en cero.
#
# Ordenar las variables categóricas ordinales en el Eje X.
#
# Intercambias ejes si es necesario por alivio visual, como texto largo.

# %%
import pandas as pd

# %%
df = pd.read_csv('./titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### ¿Cuántos pasajeros por sexo tuvo el Titanic?
# #### Objetivo:
# Visualizar cuantos pasajeros hombres y mujeres habian en el Titanic

# %%
pasajeros = df.groupby('Sex').agg({
    'PassengerId': 'count'
})
pasajeros
# Out:
#         PassengerId
# Sex
# female          314
# male            577

# %%
#pandas usa matplotlib para graficacion

pasajeros.plot.bar(
    y = 'PassengerId',
    width = 0.3,
    title = 'Numero de pasajeros por sexo'
)
# Out:
# <AxesSubplot:title={'center':'Numero de pasajeros por sexo'}, xlabel='Sex'>

# %%
import seaborn as sns

# %%
pasajeros2 = pasajeros.reset_index()
pasajeros2
# Out:
#       Sex  PassengerId
# 0  female          314
# 1    male          577

# %%
sns.barplot(
    data = pasajeros2,
    x='Sex',
    y='PassengerId'
)
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='PassengerId'>

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(
    pasajeros2['Sex'],
    pasajeros2['PassengerId']
)
# Out:
# <BarContainer object of 2 artists>
