# %% [markdown]
# # Gráfico de Dispersión (Scatter Plot)
# Gráfico que muestra los valores de dos variables de un mismo registro en nuestro dataset al mismo tiempo. En cada Eje del gráfico se coloca una variable. Se dibuja en el canvas un punto, en la coordenada correspondiente al valor de las variables por cada observación de nuestro dataset. Su objetivo es detectar si existe o no alguna correlación entre las variables en los ejes. Estos ejes usualmente son variables numéricas pero también se pueden utilizar variables categóricas ordinales.
# **Eje X**: Variable numérica o categórica
# **Eje Y**: Variable numérica o categórica
# **Otros nombres**: Gráfico de puntos, X-Y Plot.
#
# ![image-5.png](attachment:image-5.png)
#
# **Ejemplos de Uso**:
# - Como un doctor, me gustaría saber si el nivel de colesterol de una persona se correlaciona con su peso.
# - ![image.png](attachment:a7ee5730-836a-4ac8-92b5-47060d678591.png)
#
# ### Cuando utilizar
# - Quiero comprobar si existe algun tipo de correlación entre dos variables (ver imagen de tipos de correlaciones)
# - Quiero observar la distribución de dos variables al mismo tiempo.
# - Quiero hallar el tipo, y el nivel (o fuerza) de correlación entre mis variables (ver imagen de tipos de correlaciones)
# -
# ![image-6.png](attachment:image-6.png)
#
#
# ### Consejos
# - No es necesario que el Eje Y empiece en el valor del "cero". En realidad, ambos ejes deberían empezar donde empieza el rango de sus datos.
# - No utilices colores en los puntos innecesariamente.
# - Puedo introducir una 3ra o 4ta variable al gráfico con las siguientes técticas:
#   - Diferentes colores de cada punto para introducir una variable categórica.
#   - Diferentes formas en los puntos para introducir una variable categórica.
#   - Convertirlo en un gráfico de burbujas para introducir una variable numérica.
#   - Jugar con la intensidad del color de cada punto para introducir una variable numérica.
# - Si tengo muy pocos puntos en mi dataset, el resultado del gráfico no será muy útil.
# - Si hay una cantidad muy grande de puntos, el gráfico se vuelve ilegible. Con apariencia de manchas.
#   - Podemos coger una muestra, o jugar con la opacidad de los puntos
#
#
# ## En este notebook
#
# ### Datos
# Información sobre especies de pinguinos
# ### Objetivos
# 1. Encontrar alguna correlación entre las características de los pinguinos
#
# ## Referencias
# - https://datavizcatalogue.com/ES/metodos/diagrama_de_dispersion.html
# - https://datavizcatalogue.com/methods/scatterplot.html
# - https://chartio.com/learn/charts/what-is-a-scatter-plot/

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
plt.style.use('ggplot')
# Algunos ambientes van a necesitar este modo para poder visualizar los graficos de Plotly
import plotly
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('./pinguinos.csv')
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df = df.dropna()
df
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen              39.1             18.7              181.0
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
df.plot.scatter(
    x='flipper_length_mm', #Longitud aletas
    y = 'culmen_length_mm', #Longitud pico
    c = 'body_mass_g'
)
# Out:
# <Axes: xlabel='flipper_length_mm', ylabel='culmen_length_mm'>

# %% [markdown]
# Se puede analizar que la especie Gentoo al tener picos y aletas más grandes también tienden a tener masa corporal mayor respecto a las otras especies, mientras que Adelie y Chinstrap comparten masa corporal muy parecida.

# %% [markdown]
# Usando plotly

# %%
fig = px.scatter(
    df,
    x = 'flipper_length_mm',
    y= 'culmen_length_mm',
    color = 'species'
)
fig.show()

# %% [markdown]
# Podemos analizar que Gentoo es la especie con picos y aletas más grandes, mientras Adelie los más pequeños respecto a las otras especies.
# Si se analizan aparte cada especie, al parecer puede haber una relación de correlación fuerte entre las longitudes de pico y aletas en la especie Gentoo y puede intentarse realizar un ajuste lineal, para las otras dos especies, al parecer, no aparentan tener una relación tan fuerte pero es recomendable hacer el mismo ejercicio del ajuste.

# %% [markdown]
# Usando seaborn

# %%
sns.set_style('whitegrid')

# %% [markdown]
# # Gráfico de Dispersión Categórico
# En Seaborn hay un tipo de gráfico especial que me ayuda cuando quiero hacer un Scatter plot utilizando variables categóricas como los ejes. Me es útil si quiero determinar cuando una variable categórica puede estar relacionada a cambios en una variable numérica. Uno de los dos ejes tiene que ser una variable categórica y el otro una variable numérica.
# **Eje X**: Variable numérica o categórica
# **Eje Y**: Variable numérica o categórica
# **Otros nombres**: Category Plot
#
#
# ## Referencias
# - https://seaborn.pydata.org/generated/seaborn.catplot.html

# %%
sns.catplot(
    data = df,
    x = 'flipper_length_mm',
    y = 'species',
    hue = 'island'
)
# Out:
# C:\Users\jeron\anaconda32024\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#
# C:\Users\jeron\anaconda32024\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning:
#
# use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.

# %% [markdown]
# La especie Gentoo presenta una gran diferencia en la longitud de sus aletas respecto a las especies Chinstrap y Adelie, estas dos anteriores especies compartes tamaños similares en sus aletas. Otro hallazgo interesante es que la especie Gentoo solo se encuentra en la isla Biscoe, Chinstrap en la isla Dream y Adelie en todas las islas.
